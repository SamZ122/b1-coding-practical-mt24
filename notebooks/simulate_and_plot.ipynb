# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Simulate mission trajectory

# %%
from uuv_mission import dynamic
from uuv_mission import control

# Initialise controller, submarine and simulation with default parameters
controller = control.pd_controller()
sub = dynamic.Submarine()
sim = dynamic.ClosedLoop(sub, controller) 

# Get reference from mission.csv file
mission = dynamic.Mission.from_csv("/Users/samrfgh/Desktop/Eng/Year3/Scientific_coding/b1-coding-practical-mt24/data/mission.csv")

# Generate random mission reference and cave profile
#mission = dynamic.Mission.random_mission(100,100.0)
mission_data = sim.simulate_with_random_disturbances(mission)   # simulate system

mission_data.plot_completed_mission(mission)                    # plot mission and actual paths
